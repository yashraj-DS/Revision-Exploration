# %%
import time
t = time.localtime()
localtime = time.asctime(t)
localtime
import re
pattern = re.compile(r'\d{2}:\d{2}:\d{2}')
b = str(re.findall(pattern,localtime))
a = re.search(r'\d{2}',b)
a = int(a.group())
import datetime
day = datetime.datetime.now().strftime('%A')
print("Hello, Welcome to Name_Proccessing_Programme!")
name = input("Please input your name : ").strip().title()
def greet(name = "User"):
    if 1<=a<=11:
        print(f"Good Morning, {name}")
    elif 12<=a<=15:
        print(f"Good Afternoon, {name}")
    elif 16<=a<=18:
        print(f"Good Evening, {name}")
    elif 19<=a<=24:
        print(f"Good Night, {name}")
    else:
        print(f"Hello, {name}")
greet(name)
wellness = input(f"How are you {name} ? ")
common_negitive_answers_words = ["sad", "bad", "not good", "unhappy", "depressed", "angry", "frustrated",
                                "tired", "exhausted", "lonely", "hopeless", "not fine", "miserable",
                                "anxious", "stressed", "worried", "hurt", "crying", "down", "sick",
                                "broken", "in pain", "terrible", "awful", "horrible", "not okay",
                                "can't cope", "burned out", "heartbroken", "lost", "empty", "fed up"]
keywords = [word for word in common_negitive_answers_words if word in wellness.lower()]
if keywords:
    print("😔 I'm sorry to hear that. Remember, tough times don’t last. 💪")
    import random
    quotes = [
    "'Keep going, better days are coming'.",
    "'You're stronger than you think'.",
    "'This too shall pass'.",
    "'Every day is a new beginning'."
    ]
    print(random.choice(quotes))

else:
    print("Glad to hear you're doing well!")
print(f"Your good name is {name}.")
print("If we write your name in reverse form :")
print(name[::-1].upper().center(25,"-"))
print("Consonant and vowel in your name :")
vowel = [vowel for vowel in name.lower() if vowel in ["a","o","u","e","i"]]
consonant = [consonant for consonant in name.lower() if consonant not in ["a","o","u","e","i"]]
if " " in consonant:
    consonant.remove(" ")
else:
    ""
len_name = len(name.replace(" ",""))
print(f"Vowel({len(vowel)}) : {vowel}\nConsonant({len(consonant)}) : {consonant}")
print(f"Total no. of words in your name is : {len(name.replace(' ',''))}")
while True:
    z = input("If you want to check your other unknown facts of your name\nInput [YES/NO] : ")
    if z.lower()=="yes":
        print("Now, Checking your name if it is Palindrome or not....")
        if name[::]==name[::-1]:
            print("Ohh! Your name is Palindromic \nYou have a very unique name, you know!")
        else:
            print("Sorry, but it's really a rare co-incidence to have that kind of name!")
        print("let us try to make a funny nickname : ")
        print(f"Your nickname could be: {name[:3].capitalize()}y 😄")
        print("Please don't offend with this...")
        print(f"Happy {day},")
        def show_emoji_menu():
            emoji_options = {
                1: "🌟 Star",
                2: "🔥 Fire",
                3: "😊 Smile",
                4: "❤️ Heart",
                5: "🌈 Rainbow",
                6: "💎 Diamond",
                7: "🎉 Party",
                8: "🐍 Python",
                9: "👑 Crown"
                }
            print("\nChoose your favorite emoji:")
            for key, val in emoji_options.items():
                print(f"{key}. {val}")
            while True:
                try:
                    choice = int(input("Enter the number of your choice: "))
                    if choice in emoji_options:
                        emoji = emoji_options[choice][0]  # Get emoji symbol only
                        return emoji
                    else:
                        print("Please choose a valid number.")
                except ValueError:
                    print("Please enter a number.")
        def emoji_name_banner(name, emoji):
            border = emoji * (len(name) + 6)
            print("\n" + border)
            print(f"{emoji}  {name}  {emoji}")
            print(border)
        def name_letter_emoji_art(name, emoji):
            print("\nLetter-by-letter Emoji Art:")
            for char in name:
                if char != " ":
                    print(f"{emoji} {char.upper()} {emoji}")
        selected_emoji = show_emoji_menu()

        emoji_name_banner(name, selected_emoji)
        name_letter_emoji_art(name, selected_emoji)
        break
    elif z.lower()=="no":
        print(f"Happy {day}, {name}")
        break
    else:
        print("Please input in (yes/no), Invalid input found!")
# Out:
# Hello, Welcom to Name_Proccessing_Programme!
# Good Evening, Rashi
# 😔 I'm sorry to hear that. Remember, tough times don’t last. 💪
# 'This too shall pass'.
# Your good name is Rashi.
# If we write your name in reverse form :
# ----------IHSAR----------
# Consonant and vowel in your name :
# Vowel(2) : ['a', 'i']
# Consonant(3) : ['r', 's', 'h']
# Total no. of words in your name is : 5
# Happy Wednesday, Rashi
